# %%
import numpy as np
import matplotlib.pyplot as plt
import camb

# %%
H_0 = 67.4
h = H_0 / 100
omega_ch20 = 0.120
omega_bh20 = 0.0224
omega_m0 = 0.315
ns = 0.965
tau = 0.054

params = camb.CAMBparams()
params.set_cosmology(H0=H_0, ombh2=omega_bh20, omch2=omega_ch20, tau=tau)
results = camb.get_results(params)

# %%
results
# Out:
# class: <CAMBdata>
#  Params: <CAMBparams>
#    WantCls = True
#    WantTransfer = False
#    WantScalars = True
#    WantTensors = False
#    WantVectors = False
#    WantDerivedParameters = True
#    Want_cl_2D_array = True
#    Want_CMB = True
#    Want_CMB_lensing = True
#    DoLensing = True
#    NonLinear = NonLinear_none
#    Transfer: <TransferParams>
#      high_precision = False
#      accurate_massive_neutrinos = False
#      kmax = 0.9
#      k_per_logint = 0
#      PK_num_redshifts = 1
#      PK_redshifts = [0.0]
#    want_zstar = False
#    want_zdrag = False
#    min_l = 2
#    max_l = 2500
#    max_l_tensor = 600
#    max_eta_k = 6250.0
#    max_eta_k_tensor = 1200.0
#    ombh2 = 0.0224
#    omch2 = 0.12
#    omk = 0.0
#    omnuh2 = 0.000644866570625114
#    H0 = 67.4
#    TCMB = 2.7255
#    YHe = 0.24586829360147697
#    num_nu_massless = 2.0293333333333337
#    num_nu_massive = 1
#    nu_mass_eigenstates = 1
#    share_delta_neff = False
# ...

# %%
z = np.linspace(0, 1300, 100)
H = results.hubble_parameter(z) 
a = 1 / (1 + z)
Omega_m = results.get_Omega("cdm",z) + results.get_Omega("baryon",z) + results.get_Omega("nu",z)
Omega_r = results.get_Omega("photon",z) + results.get_Omega("neutrino",z)
Omega_K = results.get_Omega("K",z)
Omega_lambda = results.omega_de

# %%
plt.plot(z, Omega_m, label=r'$\Omega_m$')
plt.plot(z, Omega_r, label=r'$\Omega_r$')
plt.plot(z, Omega_K, label=r'$\Omega_K$')
plt.axhline(Omega_lambda, color='k', ls='--', label=r'$\Omega_\lambda$')
plt.xscale('log')
plt.xlabel('Redshift z')
plt.ylabel(r'$\Omega(z)$')
plt.legend()
plt.show()
